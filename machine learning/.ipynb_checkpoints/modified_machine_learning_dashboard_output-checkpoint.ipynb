# %%
import pandas as pd
import numpy as np
import csv

# %%
epas = pd.read_csv('cleaner_data.csv')
epas.head()
# Out:
#            game_id  season  week home_team  home_qb_name  home_off_epa  \
# 0  2011_01_ATL_CHI    2011     1       CHI    Jay Cutler     -0.055269
# 1   2011_01_BUF_KC    2011     1        KC   Matt Cassel     -0.372663
# 2  2011_01_CAR_ARI    2011     1       ARI    Kevin Kolb      0.132567
# 3  2011_01_CIN_CLE    2011     1       CLE    Colt McCoy     -0.150630
# 4  2011_01_DAL_NYJ    2011     1       NYJ  Mark Sanchez     -0.071235
#
#   away_team      away_qb_name  away_off_epa  def_epa_home  def_pass_epa_home  \
# 0       ATL         Matt Ryan     -0.262554     -0.262554          -0.290874
# 1       BUF  Ryan Fitzpatrick      0.223898      0.223898           0.443865
# 2       CAR        Cam Newton      0.125934      0.125934           0.348553
# 3       CIN       Andy Dalton      0.054779      0.054779          -0.018311
# 4       DAL         Tony Romo      0.050997      0.050997           0.200578
#
#    def_rush_epa_home  def_epa_away  def_pass_epa_away  def_rush_epa_away
# 0          -0.166269     -0.055269           0.014545          -0.150940
# 1           0.067607     -0.372663          -0.444717          -0.220548
# 2          -0.212117      0.132567           0.395432          -0.198872
# 3           0.127870     -0.150630          -0.214656          -0.043065
# 4          -0.188334     -0.071235          -0.027524          -0.202369

# %%
scores = pd.read_csv('/Users/tcjurgens/Documents/Data_Final_Project/NFL-Analytics-Project/lines_data/betting_info.csv').drop(columns=['Unnamed: 0'])
scores.head()
# Out:
#            game_id  season game_type  week    matchup home_team away_team  \
# 0    2011_01_NO_GB    2011       REG     1    GB v NO        GB        NO
# 1  2011_01_PIT_BAL    2011       REG     1  BAL v PIT       BAL       PIT
# 2  2011_01_ATL_CHI    2011       REG     1  CHI v ATL       CHI       ATL
# 3  2011_01_CIN_CLE    2011       REG     1  CLE v CIN       CLE       CIN
# 4  2011_01_IND_HOU    2011       REG     1  HOU v IND       HOU       IND
#
#    home_score  away_score  result  ...  weather ATS_win  ATS_loss  ATS_push  \
# 0        42.0        34.0    -8.0  ...      NaN     1.0       NaN       NaN
# 1        35.0         7.0   -28.0  ...      NaN     1.0       NaN       NaN
# 2        30.0        12.0   -18.0  ...      NaN     1.0       NaN       NaN
# 3        17.0        27.0    10.0  ...      NaN     NaN       1.0       NaN
# 4        34.0         7.0   -27.0  ...      NaN     1.0       NaN       NaN
#
#   over  under push div_game home_moneyline away_moneyline
# 0  1.0    NaN  NaN        0         -250.0          222.0
# 1  1.0    NaN  NaN        1         -125.0          113.0
# 2  1.0    NaN  NaN        0          105.0         -116.0
# 3  1.0    NaN  NaN        1         -310.0          273.0
# 4  NaN    1.0  NaN        1         -430.0          369.0
#
# [5 rows x 44 columns]

# %%
df = scores.merge(epas, on=['game_id','season','week','home_team','away_team','home_qb_name','away_qb_name'])
df.head()
# Out:
#            game_id  season game_type  week    matchup home_team away_team  \
# 0    2011_01_NO_GB    2011       REG     1    GB v NO        GB        NO
# 1  2011_01_PIT_BAL    2011       REG     1  BAL v PIT       BAL       PIT
# 2  2011_01_ATL_CHI    2011       REG     1  CHI v ATL       CHI       ATL
# 3  2011_01_CIN_CLE    2011       REG     1  CLE v CIN       CLE       CIN
# 4  2011_01_IND_HOU    2011       REG     1  HOU v IND       HOU       IND
#
#    home_score  away_score  result  ...  home_moneyline away_moneyline  \
# 0        42.0        34.0    -8.0  ...          -250.0          222.0
# 1        35.0         7.0   -28.0  ...          -125.0          113.0
# 2        30.0        12.0   -18.0  ...           105.0         -116.0
# 3        17.0        27.0    10.0  ...          -310.0          273.0
# 4        34.0         7.0   -27.0  ...          -430.0          369.0
#
#    home_off_epa  away_off_epa def_epa_home  def_pass_epa_home  \
# 0      0.355356      0.160695     0.160695           0.275887
# 1      0.184658     -0.341011    -0.341011          -0.378989
# 2     -0.055269     -0.262554    -0.262554          -0.290874
# 3     -0.150630      0.054779     0.054779          -0.018311
# 4     -0.031704     -0.364075    -0.364075          -0.326114
#
#   def_rush_epa_home def_epa_away def_pass_epa_away def_rush_epa_away
# 0         -0.119056     0.355356          0.554186          0.072405
# 1         -0.234197     0.184658          0.345858          0.033533
# 2         -0.166269    -0.055269          0.014545         -0.150940
# 3          0.127870    -0.150630         -0.214656         -0.043065
# 4         -0.444741    -0.031704          0.142812         -0.146518
#
# [5 rows x 52 columns]

# %%
df = df.loc[df['game_type'] == 'REG']

# %%
df.columns
# Out:
# Index(['game_id', 'season', 'game_type', 'week', 'matchup', 'home_team',
#        'away_team', 'home_score', 'away_score', 'result', 'spread_line',
#        'spread_result', 'total', 'total_line', 'total_result', 'overtime',
#        'qb_matchup', 'home_qb_name', 'away_qb_name', 'coaching_matchup',
#        'home_coach', 'away_coach', 'conference', 'division', 'home_rest',
#        'away_rest', 'weekday', 'gametime', 'referee', 'stadium', 'roof',
#        'surface', 'temp', 'wind', 'weather', 'ATS_win', 'ATS_loss', 'ATS_push',
#        'over', 'under', 'push', 'div_game', 'home_moneyline', 'away_moneyline',
#        'home_off_epa', 'away_off_epa', 'def_epa_home', 'def_pass_epa_home',
#        'def_rush_epa_home', 'def_epa_away', 'def_pass_epa_away',
#        'def_rush_epa_away'],
#       dtype='object')

# %% [markdown]
# drop (probably) irrelevent columns

# %%
df = df.drop(columns=['matchup','home_coach','away_coach','conference','division','weekday','gametime','referee','stadium',
'roof','surface','temp','wind','weather','ATS_win','ATS_loss','ATS_push','over','under','push','div_game','home_moneyline',
'away_moneyline','overtime','qb_matchup','coaching_matchup','spread_result','total_result'])

# %%
df.columns
# Out:
# Index(['game_id', 'season', 'game_type', 'week', 'home_team', 'away_team',
#        'home_score', 'away_score', 'result', 'spread_line', 'total',
#        'total_line', 'home_qb_name', 'away_qb_name', 'home_rest', 'away_rest',
#        'home_off_epa', 'away_off_epa', 'def_epa_home', 'def_pass_epa_home',
#        'def_rush_epa_home', 'def_epa_away', 'def_pass_epa_away',
#        'def_rush_epa_away'],
#       dtype='object')

# %% [markdown]
# # data is filtered to what we need to run our rudimentary predictions

# %% [markdown]
# shift epa stats

# %%
df['home_qb_epa_shifted'] = df.groupby('home_qb_name')['home_off_epa'].shift()
df['away_qb_epa_shifted'] = df.groupby('away_qb_name')['away_off_epa'].shift()
df['home_def_shifted'] = df.groupby('home_team')['def_epa_home'].shift()
df['away_def_shifted'] = df.groupby('away_team')['def_epa_away'].shift()
df['home_pass_def_shifted'] = df.groupby('home_team')['def_pass_epa_home'].shift()
df['away_pass_def_shifted'] = df.groupby('away_team')['def_pass_epa_away'].shift()
df['home_rush_def_shifted'] = df.groupby('home_team')['def_rush_epa_home'].shift()
df['away_rush_def_shifted'] = df.groupby('away_team')['def_rush_epa_away'].shift()

# %% [markdown]
# average epas over an interval of 5 games

# %%
df['home_qb_ewa'] = df.groupby('home_qb_name')['home_qb_epa_shifted'].transform(lambda x: x.ewm(min_periods=1, span=5).mean())
df['away_qb_ewa'] = df.groupby('away_qb_name')['away_qb_epa_shifted'].transform(lambda x: x.ewm(min_periods=1, span=5).mean())
df['home_def_ewa'] = df.groupby('home_team')['home_def_shifted'].transform(lambda x: x.ewm(min_periods=1, span=5).mean())
df['away_def_ewa'] = df.groupby('away_team')['away_def_shifted'].transform(lambda x: x.ewm(min_periods=1, span=5).mean())
df['home_pass_def_ewa'] = df.groupby('home_team')['home_pass_def_shifted'].transform(lambda x: x.ewm(min_periods=1, span=5).mean())
df['away_pass_def_ewa'] = df.groupby('away_team')['away_pass_def_shifted'].transform(lambda x: x.ewm(min_periods=1, span=5).mean())
df['home_rush_def_ewa'] = df.groupby('home_team')['home_rush_def_shifted'].transform(lambda x: x.ewm(min_periods=1, span=5).mean())
df['away_rush_def_ewa'] = df.groupby('away_team')['away_rush_def_shifted'].transform(lambda x: x.ewm(min_periods=1, span=5).mean())

# %% [markdown]
# fill nan columns w the average

# %%
df = df.fillna(df.mean())

# %% [markdown]
# assign dummy variable for wins/losses/ties

# %%
df = df.assign(home_team_win = lambda x: (x.home_score > x.away_score).astype(int), away_team_win = lambda x: (x.home_score < x.away_score).astype(int),
tie = lambda x: (x.home_score == x.away_score).astype(int))

# %%
df.columns
# Out:
# Index(['game_id', 'season', 'game_type', 'week', 'home_team', 'away_team',
#        'home_score', 'away_score', 'result', 'spread_line', 'total',
#        'total_line', 'home_qb_name', 'away_qb_name', 'home_rest', 'away_rest',
#        'home_off_epa', 'away_off_epa', 'def_epa_home', 'def_pass_epa_home',
#        'def_rush_epa_home', 'def_epa_away', 'def_pass_epa_away',
#        'def_rush_epa_away', 'home_qb_epa_shifted', 'away_qb_epa_shifted',
#        'home_def_shifted', 'away_def_shifted', 'home_pass_def_shifted',
#        'away_pass_def_shifted', 'home_rush_def_shifted',
#        'away_rush_def_shifted', 'home_qb_ewa', 'away_qb_ewa', 'home_def_ewa',
#        'away_def_ewa', 'home_pass_def_ewa', 'away_pass_def_ewa',
#        'home_rush_def_ewa', 'away_rush_def_ewa', 'home_team_win',
#        'away_team_win', 'tie'],
#       dtype='object')

# %%
df.dtypes
# Out:
# game_id                   object
# season                     int64
# game_type                 object
# week                       int64
# home_team                 object
# away_team                 object
# home_score               float64
# away_score               float64
# result                   float64
# spread_line              float64
# total                    float64
# total_line               float64
# home_qb_name              object
# away_qb_name              object
# home_rest                  int64
# away_rest                  int64
# home_off_epa             float64
# away_off_epa             float64
# def_epa_home             float64
# def_pass_epa_home        float64
# def_rush_epa_home        float64
# def_epa_away             float64
# def_pass_epa_away        float64
# def_rush_epa_away        float64
# home_qb_epa_shifted      float64
# away_qb_epa_shifted      float64
# home_def_shifted         float64
# away_def_shifted         float64
# home_pass_def_shifted    float64
# away_pass_def_shifted    float64
# home_rush_def_shifted    float64
# away_rush_def_shifted    float64
# home_qb_ewa              float64
# away_qb_ewa              float64
# home_def_ewa             float64
# away_def_ewa             float64
# home_pass_def_ewa        float64
# away_pass_def_ewa        float64
# home_rush_def_ewa        float64
# away_rush_def_ewa        float64
# home_team_win              int64
# away_team_win              int64
# tie                        int64
# dtype: object

# %% [markdown]
# checking out some correlations btwn spreads/totals

# %%
import matplotlib.pyplot as plt

# %%
df.plot.scatter(x='spread_line',y='result')
# Out:
# <AxesSubplot:xlabel='spread_line', ylabel='result'>

# %%
df.plot.scatter(x='total_line', y='total')
# Out:
# <AxesSubplot:xlabel='total_line', ylabel='total'>

# %%
corr = df.corr()
corr
# Out:
#                          season      week  home_score  away_score    result  \
# season                 1.000000 -0.072961   -0.009080    0.082779  0.062490
# week                  -0.072961  1.000000   -0.019071   -0.036309 -0.011223
# home_score            -0.009080 -0.019071    1.000000   -0.049926 -0.735942
# away_score             0.082779 -0.036309   -0.049926    1.000000  0.712943
# result                 0.062490 -0.011223   -0.735942    0.712943  1.000000
# spread_line            0.051878  0.009095   -0.321011    0.300866  0.429335
# total                  0.052287 -0.039949    0.702471    0.675753 -0.035118
# total_line             0.208136 -0.055587    0.213862    0.222081  0.000394
# home_rest              0.009215  0.009089    0.000526    0.001281  0.000499
# away_rest             -0.017804  0.022053   -0.002307   -0.002441 -0.000035
# home_off_epa           0.005092 -0.040844    0.749776   -0.169546 -0.641349
# away_off_epa           0.065776 -0.041047   -0.190477    0.764675  0.652099
# def_epa_home           0.065776 -0.041047   -0.190477    0.764675  0.652099
# def_pass_epa_home      0.054388 -0.052412   -0.215791    0.713079  0.634895
# def_rush_epa_home      0.041891  0.016949   -0.041950    0.328565  0.252184
# def_epa_away           0.005092 -0.040844    0.749776   -0.169546 -0.641349
# def_pass_epa_away     -0.012760 -0.062031    0.683201   -0.209673 -0.621809
# def_rush_epa_away      0.027273  0.032808    0.322690   -0.019939 -0.240076
# home_qb_epa_shifted    0.003315 -0.040855    0.123623   -0.009043 -0.092926
# away_qb_epa_shifted    0.053005 -0.039507   -0.052536    0.117536  0.116561
# home_def_shifted       0.059575 -0.001351   -0.025499    0.105646  0.089519
# away_def_shifted       0.005495 -0.011301    0.038279   -0.012441 -0.035309
# home_pass_def_shifted  0.051887 -0.015352   -0.028703    0.084905  0.077709
# away_pass_def_shifted -0.014859 -0.020274    0.025330   -0.024820 -0.034609
# home_rush_def_shifted  0.032917  0.032424   -0.015195    0.070288  0.058315
# away_rush_def_shifted  0.027500  0.029136    0.036874    0.013435 -0.016782
# home_qb_ewa           -0.008011 -0.042277    0.205601   -0.038789 -0.170647
# away_qb_ewa            0.073885 -0.036132   -0.067164    0.182405  0.170806
# home_def_ewa           0.098327  0.015280   -0.041599    0.141286  0.124983
# away_def_ewa          -0.000079 -0.002681    0.079653   -0.027393 -0.074494
# home_pass_def_ewa      0.087307  0.013015   -0.043753    0.120011  0.112073
# away_pass_def_ewa     -0.037787 -0.003366    0.070769   -0.049433 -0.083197
# home_rush_def_ewa      0.067159  0.022152   -0.034248    0.092566  0.086795
# away_rush_def_ewa      0.050768  0.005762    0.055667    0.013967 -0.029616
# home_team_win         -0.037053 -0.002128    0.560705   -0.563796 -0.775861
# away_team_win          0.036155  0.006556   -0.561503    0.562574  0.775593
# tie                    0.007998 -0.038158    0.003045    0.014383  0.007612
#
#                        spread_line     total  total_line  home_rest  \
# season                    0.051878  0.052287    0.208136   0.009215
# week                      0.009095 -0.039949   -0.055587   0.009089
# home_score               -0.321011  0.702471    0.213862   0.000526
# away_score                0.300866  0.675753    0.222081   0.001281
# result                    0.429335 -0.035118    0.000394   0.000499
# spread_line               1.000000 -0.022525    0.001453  -0.041812
# total                    -0.022525  1.000000    0.316095   0.001301
# total_line                0.001453  0.316095    1.000000   0.013889
# home_rest                -0.041812  0.001301    0.013889   1.000000
# away_rest                 0.017668 -0.003442    0.031820   0.233724
# home_off_epa             -0.300895  0.432553    0.240382   0.005440
# away_off_epa              0.300272  0.404326    0.241583  -0.005014
# def_epa_home              0.300272  0.404326    0.241583  -0.005014
# def_pass_epa_home         0.276291  0.348876    0.214053   0.001519
# def_rush_epa_home         0.140929  0.203174    0.091986  -0.017779
# def_epa_away             -0.300895  0.432553    0.240382   0.005440
# def_pass_epa_away        -0.269802  0.354822    0.198897  -0.004151
# def_rush_epa_away        -0.133743  0.223952    0.127254   0.008289
# home_qb_epa_shifted      -0.253701  0.084796    0.262592   0.019663
# away_qb_epa_shifted       0.234967  0.044982    0.240247  -0.035882
# home_def_shifted          0.179827  0.056464    0.148477  -0.024621
# away_def_shifted         -0.125545  0.019386    0.103801   0.030412
# home_pass_def_shifted     0.174588  0.039319    0.119982  -0.019426
# away_pass_def_shifted    -0.135052  0.001009    0.067564   0.032246
# home_rush_def_shifted     0.091717  0.038873    0.099848  -0.011809
# away_rush_def_shifted    -0.020864  0.036789    0.078759   0.017870
# home_qb_ewa              -0.392730  0.124102    0.349048   0.018991
# away_qb_ewa               0.350220  0.080412    0.354729  -0.025874
# home_def_ewa              0.276978  0.069978    0.203759  -0.008338
# away_def_ewa             -0.220336  0.039267    0.169079   0.024661
# home_pass_def_ewa         0.274262  0.053228    0.172015   0.002333
# away_pass_def_ewa        -0.238049  0.017005    0.103087   0.021095
# home_rush_def_ewa         0.151028  0.040687    0.123775  -0.018001
# away_rush_def_ewa        -0.066645  0.051038    0.159303   0.028850
# home_team_win            -0.376852  0.012066   -0.028619  -0.013623
# away_team_win             0.378487 -0.013525    0.030997   0.012905
# tie                      -0.011524  0.012497   -0.020308   0.006283
#
#                        away_rest  ...  away_qb_ewa  home_def_ewa  \
# season                 -0.017804  ...     0.073885      0.098327
# week                    0.022053  ...    -0.036132      0.015280
# home_score             -0.002307  ...    -0.067164     -0.041599
# away_score             -0.002441  ...     0.182405      0.141286
# result                 -0.000035  ...     0.170806      0.124983
# spread_line             0.017668  ...     0.350220      0.276978
# total                  -0.003442  ...     0.080412      0.069978
# total_line              0.031820  ...     0.354729      0.203759
# home_rest               0.233724  ...    -0.025874     -0.008338
# away_rest               1.000000  ...    -0.003233     -0.046833
# home_off_epa           -0.007023  ...    -0.027512     -0.022165
# away_off_epa           -0.005272  ...     0.203373      0.172856
# def_epa_home           -0.005272  ...     0.203373      0.172856
# def_pass_epa_home      -0.013195  ...     0.177598      0.153727
# def_rush_epa_home       0.038899  ...     0.093429      0.090697
# def_epa_away           -0.007023  ...    -0.027512     -0.022165
# def_pass_epa_away      -0.005936  ...    -0.036500     -0.024701
# def_rush_epa_away      -0.012536  ...     0.011218      0.010574
# home_qb_epa_shifted     0.051217  ...     0.022204      0.002509
# away_qb_epa_shifted    -0.011365  ...     0.782081     -0.019412
# home_def_shifted       -0.029329  ...    -0.003293      0.758060
# away_def_shifted        0.032590  ...     0.006195      0.001070
# home_pass_def_shifted  -0.026864  ...    -0.016091      0.684223
# away_pass_def_shifted   0.019366  ...    -0.040806     -0.005303
# home_rush_def_shifted  -0.005032  ...     0.031507      0.355766
# away_rush_def_shifted   0.040224  ...     0.062228      0.002464
# home_qb_ewa             0.058764  ...     0.015478      0.000002
# away_qb_ewa            -0.003233  ...     1.000000     -0.016237
# home_def_ewa           -0.046833  ...    -0.016237      1.000000
# away_def_ewa            0.022129  ...     0.008765     -0.002710
# home_pass_def_ewa      -0.040875  ...    -0.024493      0.915816
# away_pass_def_ewa       0.012825  ...    -0.070543     -0.012273
# home_rush_def_ewa      -0.022048  ...     0.021406      0.540075
# away_rush_def_ewa       0.023097  ...     0.108033      0.002225
# home_team_win          -0.021571  ...    -0.150526     -0.116490
# away_team_win           0.019738  ...     0.149752      0.118672
# tie                     0.015952  ...     0.007700     -0.018021
#
#                        away_def_ewa  home_pass_def_ewa  away_pass_def_ewa  \
# season                    -0.000079           0.087307          -0.037787
# week                      -0.002681           0.013015          -0.003366
# home_score                 0.079653          -0.043753           0.070769
# away_score                -0.027393           0.120011          -0.049433
# result                    -0.074494           0.112073          -0.083197
# spread_line               -0.220336           0.274262          -0.238049
# total                      0.039267           0.053228           0.017005
# total_line                 0.169079           0.172015           0.103087
# home_rest                  0.024661           0.002333           0.021095
# away_rest                  0.022129          -0.040875           0.012825
# home_off_epa               0.111284          -0.033917           0.094501
# away_off_epa              -0.005402           0.136717          -0.032075
# def_epa_home              -0.005402           0.136717          -0.032075
# def_pass_epa_home         -0.010276           0.126750          -0.033293
# def_rush_epa_home         -0.015945           0.065264          -0.023986
# def_epa_away               0.111284          -0.033917           0.094501
# def_pass_epa_away          0.083733          -0.027599           0.075013
# def_rush_epa_away          0.086399          -0.011089           0.059969
# home_qb_epa_shifted       -0.018115          -0.035808          -0.029395
# away_qb_epa_shifted        0.018830          -0.029546          -0.045588
# home_def_shifted           0.002255           0.693223          -0.008149
# away_def_shifted           0.754119          -0.005917           0.688074
# home_pass_def_shifted     -0.004330           0.753851          -0.005341
# away_pass_def_shifted      0.663398          -0.006657           0.752579
# home_rush_def_shifted      0.019238           0.097267          -0.009676
# away_rush_def_shifted      0.369724          -0.006086           0.084156
# home_qb_ewa               -0.022161          -0.052879          -0.029005
# away_qb_ewa                0.008765          -0.024493          -0.070543
# home_def_ewa              -0.002710           0.915816          -0.012273
# away_def_ewa               1.000000          -0.004385           0.900090
# home_pass_def_ewa         -0.004385           1.000000          -0.007750
# away_pass_def_ewa          0.900090          -0.007750           1.000000
# home_rush_def_ewa          0.013344           0.200514          -0.011697
# away_rush_def_ewa          0.526828          -0.003007           0.154467
# home_team_win              0.054600          -0.102569           0.064836
# away_team_win             -0.053489           0.105850          -0.063832
# tie                       -0.009954          -0.027593          -0.009098
#
#                        home_rush_def_ewa  away_rush_def_ewa  home_team_win  \
# season                          0.067159           0.050768      -0.037053
# week                            0.022152           0.005762      -0.002128
# home_score                     -0.034248           0.055667       0.560705
# away_score                      0.092566           0.013967      -0.563796
# result                          0.086795          -0.029616      -0.775861
# spread_line                     0.151028          -0.066645      -0.376852
# total                           0.040687           0.051038       0.012066
# total_line                      0.123775           0.159303      -0.028619
# home_rest                      -0.018001           0.028850      -0.013623
# away_rest                      -0.022048           0.023097      -0.021571
# home_off_epa                    0.000157           0.076678       0.506086
# away_off_epa                    0.135051           0.028376      -0.502940
# def_epa_home                    0.135051           0.028376      -0.502940
# def_pass_epa_home               0.107864           0.016798      -0.504778
# def_rush_epa_home               0.089433           0.012510      -0.182795
# def_epa_away                    0.000157           0.076678       0.506086
# def_pass_epa_away              -0.008735           0.056972       0.505269
# def_rush_epa_away               0.030657           0.075010       0.162313
# home_qb_epa_shifted             0.034904           0.015014       0.077315
# away_qb_epa_shifted             0.027482           0.084610      -0.102998
# home_def_shifted                0.406522           0.010246      -0.085723
# away_def_shifted                0.023117           0.376133       0.005064
# home_pass_def_shifted           0.129945           0.001026      -0.072011
# away_pass_def_shifted           0.007243           0.086273       0.016414
# home_rush_def_shifted           0.748776           0.040397      -0.057409
# away_rush_def_shifted           0.029546           0.750730      -0.018543
# home_qb_ewa                     0.046094           0.005906       0.140777
# away_qb_ewa                     0.021406           0.108033      -0.150526
# home_def_ewa                    0.540075           0.002225      -0.116490
# away_def_ewa                    0.013344           0.526828       0.054600
# home_pass_def_ewa               0.200514          -0.003007      -0.102569
# away_pass_def_ewa              -0.011697           0.154467       0.064836
# home_rush_def_ewa               1.000000           0.035001      -0.084506
# away_rush_def_ewa               0.035001           1.000000       0.013760
# home_team_win                  -0.084506           0.013760       1.000000
# away_team_win                   0.082178          -0.013065      -0.993280
# tie                             0.020648          -0.006086      -0.064773
#
#                        away_team_win       tie
# season                      0.036155  0.007998
# week                        0.006556 -0.038158
# home_score                 -0.561503  0.003045
# away_score                  0.562574  0.014383
# result                      0.775593  0.007612
# spread_line                 0.378487 -0.011524
# total                      -0.013525  0.012497
# total_line                  0.030997 -0.020308
# home_rest                   0.012905  0.006283
# away_rest                   0.019738  0.015952
# home_off_epa               -0.507202  0.006167
# away_off_epa                0.500779  0.022068
# def_epa_home                0.500779  0.022068
# def_pass_epa_home           0.502396  0.023982
# def_rush_epa_home           0.184277 -0.011533
# def_epa_away               -0.507202  0.006167
# def_pass_epa_away          -0.503964 -0.014706
# def_rush_epa_away          -0.167168  0.040753
# home_qb_epa_shifted        -0.079873  0.021525
# away_qb_epa_shifted         0.101194  0.016259
# home_def_shifted            0.083739  0.017694
# away_def_shifted           -0.005205  0.001179
# home_pass_def_shifted       0.072251 -0.001572
# away_pass_def_shifted      -0.016442  0.000132
# home_rush_def_shifted       0.052033  0.046745
# away_rush_def_shifted       0.016773  0.015392
# home_qb_ewa                -0.142828  0.016722
# away_qb_ewa                 0.149752  0.007700
# home_def_ewa                0.118672 -0.018021
# away_def_ewa               -0.053489 -0.009954
# home_pass_def_ewa           0.105850 -0.027593
# away_pass_def_ewa          -0.063832 -0.009098
# home_rush_def_ewa           0.082178  0.020648
# away_rush_def_ewa          -0.013065 -0.006086
# home_team_win              -0.993280 -0.064773
# away_team_win               1.000000 -0.051154
# tie                        -0.051154  1.000000
#
# [37 rows x 37 columns]

# %%
#from statsmodels.graphics.correlation import plot_corr

#correlation_viz = plot_corr(corr, xnames = corr.columns)

# %%
target = 'home_team_win'
features = ['spread_line','total_line','home_rest','away_rest','home_qb_ewa','away_qb_ewa','home_def_ewa','away_def_ewa',
'home_pass_def_ewa','away_pass_def_ewa','home_rush_def_ewa','away_rush_def_ewa']

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
X = df.loc[df['season'] != 2021, features].values
y = df.loc[df['season'] != 2021, target].values

clf = LogisticRegression()
clf.fit(X, y)
# Out:
# /Users/tcjurgens/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression()

# %%
accuracy_scores = cross_val_score(clf, X, y, cv=10)
log_losses = cross_val_score(clf, X, y, cv=10, scoring='neg_log_loss')

print('Model Accuracy:', np.mean(accuracy_scores))
# Out:
# /Users/tcjurgens/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /Users/tcjurgens/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /Users/tcjurgens/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /Users/tcjurgens/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /Users/tcjurgens/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /Users/tcjurgens/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /Users/tcjurgens/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /Users/tcjurgens/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /Users/tcjurgens/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /Users/tcjurgens/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Model Accuracy: 0.6609375
# /Users/tcjurgens/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /Users/tcjurgens/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
print('Neg log loss:', np.mean(log_losses))
# Out:
# Neg log loss: -0.6090261103428142

# %%
data_2021 = df.loc[(df['season'] == 2021)].assign(
    predicted_winner = lambda x: clf.predict(x[features]),
    home_team_win_probability = lambda x: clf.predict_proba(x[features])[:, 1]
)\
[['home_team', 'away_team', 'week', 'predicted_winner', 'home_team_win_probability', 'home_team_win']]

data_2021['actual_winner'] = data_2021.apply(lambda x: x.home_team if x.home_team_win else x.away_team, axis=1)
data_2021['predicted_winner'] = data_2021.apply(lambda x: x.home_team if x.predicted_winner == 1 else x.away_team, axis=1)
data_2021['win_probability'] = data_2021.apply(lambda x: x.home_team_win_probability if x.predicted_winner == x.home_team else 1 - x.home_team_win_probability, axis=1)
data_2021['correct_prediction'] = (data_2021['predicted_winner'] == data_2021['actual_winner']).astype(int)

data_2021 = data_2021.drop(columns=['home_team_win_probability', 'home_team_win'])

data_2021.sort_values(by='win_probability', ascending=False).reset_index(drop=True).head(40)
# Out:
#    home_team away_team  week predicted_winner actual_winner  win_probability  \
# 0        ARI       HOU     7              ARI           ARI         0.958839
# 1        BUF       HOU     4              BUF           BUF         0.941524
# 2        HOU        LA     8               LA            LA         0.929047
# 3         LA       DET     7               LA            LA         0.915262
# 4        JAX       BUF     9              BUF           JAX         0.910612
# 5        NYJ       BUF    10              BUF           NYJ         0.890231
# 6        BUF       MIA     8              BUF           BUF         0.878198
# 7        IND       HOU     6              IND           IND         0.877188
# 8        WAS        TB    10               TB           WAS         0.871175
# 9         TB       CHI     7               TB            TB         0.869312
# 10       CLE       HOU     2              CLE           CLE         0.866147
# 11        TB       ATL     2               TB            TB         0.857714
# 12       NYJ       CIN     8              CIN           NYJ         0.848960
# 13        TB       MIA     5               TB            TB         0.844985
# 14       IND       NYJ     9              IND           IND         0.828372
# 15       DEN       NYJ     3              DEN           DEN         0.821572
# 16        LA       CHI     1               LA            LA         0.817176
# 17       DET        SF     1               SF            SF         0.815340
# 18       DAL       DEN     9              DAL           DEN         0.810673
# 19        GB       DET     2               GB            GB         0.805262
# 20        TB       DAL     1               TB            TB         0.804102
# 21       IND       JAX    10              IND           IND         0.799309
# 22       DAL       ATL    10              DAL           DAL         0.797187
# 23        KC       NYG     8               KC            KC         0.791350
# 24       MIN       DET     5              MIN           MIN         0.780697
# 25       BUF       WAS     3              BUF           BUF         0.772307
# 26       NYG        LA     6               LA            LA         0.772067
# 27       PHI        KC     4               KC            KC         0.771953
# 28       JAX       ARI     3              ARI           ARI         0.765424
# 29       CIN       JAX     4              CIN           CIN         0.763907
# 30       WAS        KC     6               KC            KC         0.762478
# 31        GB       WAS     7               GB            GB         0.754902
# 32       DET       BAL     3              BAL           BAL         0.753912
# 33        NO       NYG     4               NO           NYG         0.753855
# 34       PHI        TB     6               TB            TB         0.751914
# 35       PIT       CHI     9              PIT           PIT         0.749456
# 36       HOU        NE     5               NE            NE         0.747457
# 37       BAL       IND     5              BAL           BAL         0.745141
# 38       TEN       BUF     6              BUF           TEN         0.741805
# 39       HOU       CAR     3              CAR           CAR         0.740829
#
#     correct_prediction
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    0
# 5                    0
# 6                    1
# 7                    1
# 8                    0
# 9                    1
# 10                   1
# 11                   1
# 12                   0
# 13                   1
# 14                   1
# 15                   1
# 16                   1
# 17                   1
# 18                   0
# 19                   1
# 20                   1
# 21                   1
# 22                   1
# 23                   1
# 24                   1
# 25                   1
# 26                   1
# 27                   1
# 28                   1
# 29                   1
# 30                   1
# 31                   1
# 32                   1
# 33                   0
# 34                   1
# 35                   1
# 36                   1
# 37                   1
# 38                   0
# 39                   1
